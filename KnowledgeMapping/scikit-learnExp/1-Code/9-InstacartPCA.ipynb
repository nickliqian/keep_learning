# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA

# %%
# 订单与商品
prior = pd.read_csv('D://A//data//instacart//order_products__prior.csv')
# 商品购买信息
product = pd.read_csv('D://A//data//instacart//products.csv')
# 用户与订单信息
order = pd.read_csv('D://A//data//instacart//orders.csv')
# 商品与类别
aisles = pd.read_csv('D://A//data//instacart//aisles.csv')

# %%
pp = pd.merge(prior, product, on=['product_id', 'product_id'])
po = pd.merge(pp, order, on=['order_id', 'order_id'])
res = pd.merge(po, aisles, on=['aisle_id', 'aisle_id'])

# %%
res
# Out:
#           order_id  product_id  add_to_cart_order  reordered  \
# 0                2       33120                  1          1
# 1               26       33120                  5          0
# 2              120       33120                 13          0
# 3              327       33120                  5          1
# 4              390       33120                 28          1
# 5              537       33120                  2          1
# 6              582       33120                  7          1
# 7              608       33120                  5          1
# 8              623       33120                  1          1
# 9              689       33120                  4          1
# 10             689       35921                  3          1
# 11             726       33120                  3          1
# 12             726       32655                  5          1
# 13             771       33120                 29          1
# 14             800       33120                  3          1
# 15             901       33120                  3          1
# 16            1005       33120                  5          1
# 17            1097       33120                 14          1
# 18            1193       33120                  5          1
# 19            1300       33120                  1          1
# 20            1887       33120                  6          1
# 21            2082       33120                 20          0
# 22            2082       11520                  3          0
# 23            2357       33120                  6          1
# 24            2551       33120                  6          1
# 25            2652       33120                  1          1
# 26            2846       33120                 10          1
# 27            2846       30233                 11          1
# 28            2929       33120                  1          0
# 29            3031       33120                  2          1
# ...            ...         ...                ...        ...
# 32434459    549776       20088                  1          1
# 32434460    947413       20088                  1          0
# 32434461   1441921       20088                  1          0
# 32434462   2716411       20088                  1          0
# 32434463   2853474       20088                  1          1
# 32434464    336601       18351                  1          0
# 32434465    375037       18351                  1          1
# 32434466    543893       18351                  1          1
# 32434467   1388850       18351                  1          0
# 32434468   1765746       18351                  1          1
# 32434469   2321015       12825                  1          0
# 32434470    488354        2216                  1          1
# 32434471    677775        2216                  1          1
# 32434472   1105640        2216                  1          1
# 32434473   1565508        2216                  1          1
# 32434474   1618508        2216                  1          1
# 32434475   1708658        2216                  1          1
# 32434476   2007360        2216                  1          1
# 32434477   2209886        2216                  1          1
# 32434478   2456326        2216                  1          1
# 32434479   2637713        2216                  1          0
# 32434480   3091866        2216                  1          1
# 32434481   3134093        2216                  1          1
# 32434482    886132       12825                  1          1
# 32434483   1894201       25992                  1          0
# 32434484   3243156       20731                  1          0
# 32434485    860862       30582                  1          0
# 32434486   1333472       27906                  1          0
# 32434487   2122701       26086                  1          1
# 32434488   3168475       26086                  1          1
#
#                                          product_name  aisle_id  \
# 0                                  Organic Egg Whites        86
# 1                                  Organic Egg Whites        86
# 2                                  Organic Egg Whites        86
# 3                                  Organic Egg Whites        86
# 4                                  Organic Egg Whites        86
# 5                                  Organic Egg Whites        86
# 6                                  Organic Egg Whites        86
# 7                                  Organic Egg Whites        86
# 8                                  Organic Egg Whites        86
# 9                                  Organic Egg Whites        86
# 10                   Organic Large Grade A Brown Eggs        86
# 11                                 Organic Egg Whites        86
# 12                  Organic Large Grade AA Brown Eggs        86
# 13                                 Organic Egg Whites        86
# 14                                 Organic Egg Whites        86
# 15                                 Organic Egg Whites        86
# 16                                 Organic Egg Whites        86
# 17                                 Organic Egg Whites        86
# 18                                 Organic Egg Whites        86
# 19                                 Organic Egg Whites        86
# 20                                 Organic Egg Whites        86
# 21                                 Organic Egg Whites        86
# 22                                Large Alfresco Eggs        86
# 23                                 Organic Egg Whites        86
# 24                                 Organic Egg Whites        86
# 25                                 Organic Egg Whites        86
# 26                                 Organic Egg Whites        86
# 27        Organic Large Brown Grade AA Cage Free Eggs        86
# 28                                 Organic Egg Whites        86
# 29                                 Organic Egg Whites        86
# ...                                               ...       ...
# 32434459                                 Brut Premier       134
# 32434460                                 Brut Premier       134
# 32434461                                 Brut Premier       134
# 32434462                                 Brut Premier       134
# 32434463                                 Brut Premier       134
# 32434464             Sparkling Wine, Rose, California       134
# 32434465             Sparkling Wine, Rose, California       134
# 32434466             Sparkling Wine, Rose, California       134
# 32434467             Sparkling Wine, Rose, California       134
# 32434468             Sparkling Wine, Rose, California       134
# 32434469                                      Sangria       134
# 32434470                         California Champagne       134
# 32434471                         California Champagne       134
# 32434472                         California Champagne       134
# 32434473                         California Champagne       134
# 32434474                         California Champagne       134
# 32434475                         California Champagne       134
# 32434476                         California Champagne       134
# 32434477                         California Champagne       134
# 32434478                         California Champagne       134
# 32434479                         California Champagne       134
# 32434480                         California Champagne       134
# 32434481                         California Champagne       134
# 32434482                                      Sangria       134
# 32434483                            Cristal Champagne       134
# 32434484                              Straight Sherry       134
# 32434485                            Natural Champagne       134
# 32434486                           Imperial Champagne       134
# 32434487                 La Grand Dame Brut Champagne       134
# 32434488                 La Grand Dame Brut Champagne       134
#
#           department_id  user_id eval_set  order_number  order_dow  \
# 0                    16   202279    prior             3          5
# 1                    16   153404    prior             2          0
# 2                    16    23750    prior            11          6
# 3                    16    58707    prior            21          6
# 4                    16   166654    prior            48          0
# 5                    16   180135    prior            15          2
# 6                    16   193223    prior             6          2
# 7                    16    91030    prior            11          3
# 8                    16    37804    prior            63          3
# 9                    16   108932    prior            16          1
# 10                   16   108932    prior            16          1
# 11                   16    57362    prior            25          2
# 12                   16    57362    prior            25          2
# 13                   16    73968    prior            16          0
# 14                   16   132856    prior             3          5
# 15                   16   160657    prior            31          1
# 16                   16   108796    prior            11          2
# 17                   16    30502    prior             5          4
# 18                   16   113928    prior            12          4
# 19                   16    29456    prior             6          4
# 20                   16    25085    prior            78          1
# 21                   16   108338    prior             3          3
# 22                   16   108338    prior             3          3
# 23                   16    67308    prior            11          5
# 24                   16    20944    prior            54          6
# 25                   16    37557    prior            15          1
# 26                   16   168005    prior            31          4
# 27                   16   168005    prior            31          4
# 28                   16   173056    prior             4          1
# 29                   16     2555    prior            21          6
# ...                 ...      ...      ...           ...        ...
# 32434459              5   119429    prior            10          2
# 32434460              5   119429    prior             6          2
# 32434461              5   179737    prior             2          5
# 32434462              5    79830    prior             2          6
# 32434463              5   119429    prior            11          3
# 32434464              5    62984    prior             1          5
# 32434465              5     2909    prior            17          3
# 32434466              5   113857    prior             6          6
# 32434467              5    80882    prior            56          2
# 32434468              5     2909    prior            14          1
# 32434469              5    33083    prior            12          4
# 32434470              5   161786    prior            25          6
# 32434471              5   161786    prior            15          2
# 32434472              5   161786    prior            16          2
# 32434473              5   161786    prior            29          2
# 32434474              5   161786    prior            19          3
# 32434475              5   161786    prior            18          4
# 32434476              5   161786    prior            24          6
# 32434477              5   161786    prior            28          4
# 32434478              5   161786    prior            27          3
# 32434479              5   161786    prior            14          6
# 32434480              5   161786    prior            22          5
# 32434481              5   161786    prior            21          3
# 32434482              5   137204    prior            13          6
# 32434483              5   168275    prior            24          0
# 32434484              5   166400    prior             3          1
# 32434485              5   104017    prior            13          5
# 32434486              5    62079    prior            10          3
# 32434487              5    77799    prior             2          3
# 32434488              5     5223    prior             7          3
#
#           order_hour_of_day  days_since_prior_order  \
# 0                         9                     8.0
# 1                        16                     7.0
# 2                         8                    10.0
# 3                         9                     8.0
# 4                        12                     9.0
# 5                         8                     3.0
# 6                        19                    10.0
# 7                        21                    12.0
# 8                        12                     3.0
# 9                        13                     3.0
# 10                       13                     3.0
# 11                       17                     7.0
# 12                       17                     7.0
# 13                       17                     7.0
# 14                        7                     3.0
# 15                       23                     8.0
# 16                       14                     6.0
# 17                        0                     8.0
# 18                       21                     9.0
# 19                        9                    20.0
# 20                       10                     3.0
# 21                       13                    10.0
# 22                       13                    10.0
# 23                       12                     9.0
# 24                       18                     4.0
# 25                       14                    21.0
# 26                       15                    15.0
# 27                       15                    15.0
# 28                       10                    21.0
# 29                        9                     6.0
# ...                     ...                     ...
# 32434459                 11                     7.0
# 32434460                  9                    19.0
# 32434461                 12                    17.0
# 32434462                 14                    27.0
# 32434463                 10                     1.0
# 32434464                  9                     NaN
# 32434465                  9                     7.0
# 32434466                  7                     1.0
# 32434467                 16                    26.0
# 32434468                  9                     5.0
# 32434469                 14                     6.0
# 32434470                  8                     7.0
# 32434471                 12                    10.0
# 32434472                 13                     0.0
# 32434473                 12                     5.0
# 32434474                 12                     6.0
# 32434475                  0                     6.0
# 32434476                 11                     5.0
# 32434477                  9                     1.0
# 32434478                 15                     0.0
# 32434479                  3                    20.0
# 32434480                 13                     2.0
# 32434481                 15                     3.0
# 32434482                  8                    13.0
# 32434483                 14                    18.0
# 32434484                 13                    12.0
# 32434485                 14                    18.0
# 32434486                 10                    10.0
# 32434487                 14                     3.0
# 32434488                 13                     2.0
#
#                                aisle
# 0                               eggs
# 1                               eggs
# 2                               eggs
# 3                               eggs
# 4                               eggs
# 5                               eggs
# 6                               eggs
# 7                               eggs
# 8                               eggs
# 9                               eggs
# 10                              eggs
# 11                              eggs
# 12                              eggs
# 13                              eggs
# 14                              eggs
# 15                              eggs
# 16                              eggs
# 17                              eggs
# 18                              eggs
# 19                              eggs
# 20                              eggs
# 21                              eggs
# 22                              eggs
# 23                              eggs
# 24                              eggs
# 25                              eggs
# 26                              eggs
# 27                              eggs
# 28                              eggs
# 29                              eggs
# ...                              ...
# 32434459  specialty wines champagnes
# 32434460  specialty wines champagnes
# 32434461  specialty wines champagnes
# 32434462  specialty wines champagnes
# 32434463  specialty wines champagnes
# 32434464  specialty wines champagnes
# 32434465  specialty wines champagnes
# 32434466  specialty wines champagnes
# 32434467  specialty wines champagnes
# 32434468  specialty wines champagnes
# 32434469  specialty wines champagnes
# 32434470  specialty wines champagnes
# 32434471  specialty wines champagnes
# 32434472  specialty wines champagnes
# 32434473  specialty wines champagnes
# 32434474  specialty wines champagnes
# 32434475  specialty wines champagnes
# 32434476  specialty wines champagnes
# 32434477  specialty wines champagnes
# 32434478  specialty wines champagnes
# 32434479  specialty wines champagnes
# 32434480  specialty wines champagnes
# 32434481  specialty wines champagnes
# 32434482  specialty wines champagnes
# 32434483  specialty wines champagnes
# 32434484  specialty wines champagnes
# 32434485  specialty wines champagnes
# 32434486  specialty wines champagnes
# 32434487  specialty wines champagnes
# 32434488  specialty wines champagnes
#
# [32434489 rows x 14 columns]

# %%
data = pd.crosstab(res['order_id'], res['aisle_id'])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-9-b031b37a9395> in <module>()
# ----> 1 data = pd.crosstab(res['order_id'], res['aisle_id'])
#
# d:\pyinstall\virset\virpy360set\tf\lib\site-packages\pandas\core\reshape\pivot.py in crosstab(index, columns, values, rownames, colnames, aggfunc, margins, margins_name, dropna, normalize)
#     464     table = df.pivot_table('__dummy__', index=rownames, columns=colnames,
#     465                            margins=margins, margins_name=margins_name,
# --> 466                            dropna=dropna, **kwargs)
#     467
#     468     # Post-process
#
# d:\pyinstall\virset\virpy360set\tf\lib\site-packages\pandas\core\frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#    4443                            aggfunc=aggfunc, fill_value=fill_value,
#    4444                            margins=margins, dropna=dropna,
# -> 4445                            margins_name=margins_name)
#    4446
#    4447     def stack(self, level=-1, dropna=True):
#
# d:\pyinstall\virset\virpy360set\tf\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#      95             else:
#      96                 to_unstack.append(name)
# ---> 97         table = agged.unstack(to_unstack)
#      98
#      99     if not dropna:
#
# d:\pyinstall\virset\virpy360set\tf\lib\site-packages\pandas\core\frame.py in unstack(self, level, fill_value)
#    4544         """
#    4545         from pandas.core.reshape.reshape import unstack
# -> 4546         return unstack(self, level, fill_value)
#    4547
#    4548     _shared_docs['melt'] = ("""
#
# d:\pyinstall\virset\virpy360set\tf\lib\site-packages\pandas\core\reshape\reshape.py in unstack(obj, level, fill_value)
#     467     if isinstance(obj, DataFrame):
#     468         if isinstance(obj.index, MultiIndex):
# --> 469             return _unstack_frame(obj, level, fill_value=fill_value)
#     470         else:
#     471             return obj.T.stack(dropna=False)
#
# d:\pyinstall\virset\virpy360set\tf\lib\site-packages\pandas\core\reshape\reshape.py in _unstack_frame(obj, level, fill_value)
#     487                                value_columns=obj.columns,
#     488                                fill_value=fill_value)
# --> 489         return unstacker.get_result()
#     490
#     491
#
# d:\pyinstall\virset\virpy360set\tf\lib\site-packages\pandas\core\reshape\reshape.py in get_result(self)
#     163         # TODO: find a better way than this masking business
#     164
# --> 165         values, value_mask = self.get_new_values()
#     166         columns = self.get_new_columns()
#     167         index = self.get_new_index()
#
# d:\pyinstall\virset\virpy360set\tf\lib\site-packages\pandas\core\reshape\reshape.py in get_new_values(self)
#     214         else:
#     215             dtype, fill_value = maybe_promote(values.dtype, self.fill_value)
# --> 216             new_values = np.empty(result_shape, dtype=dtype)
#     217             new_values.fill(fill_value)
#     218
#
# MemoryError:

# %%
data.head(10)

# %%
pca = PCA(n_components=6)
p_data = pca.fit_transform(data)

# %%
p_data
