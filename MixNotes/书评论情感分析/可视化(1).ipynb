# %%
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import jieba
import wordcloud

# %%
font_path = "/Users/nick/Desktop/project/0data/a/SimHei.ttf"
p1_path = "/Users/nick/Desktop/project/0data/a/1112 3D-printed-car-for-imts .xlsx"
p2_path = "/Users/nick/Desktop/project/0data/a/1112 LM-SF01(1).xlsx"
p3_path = "/Users/nick/Desktop/project/0data/a/1112 RF.xlsx"

# %%
df1 = pd.read_excel(p1_path)
df2 = pd.read_excel(p2_path)
df3 = pd.read_excel(p3_path)

# %%
df1.head()
# Out:
#      user reuser                       date                  action  \
# 0  AlexFi    NaN  2014-01-14T17:11:00+00:00         created a topic
# 1  Jearle    NaN  2014-01-17T16:17:33+00:00         created a topic
# 2  Jearle    NaN  2014-01-17T16:24:22+00:00         created a topic
# 3  Jearle    NaN  2014-01-17T16:30:21+00:00         created a topic
# 4  Jearle    NaN  2014-01-17T16:36:37+00:00  commented on the topic
#
#                              activity  \
# 0       Large Scale Gantry FDM/Router
# 1                           Fasteners
# 2                       FDM Materials
# 3  Frame Geometry and Infill Patterns
# 4  Frame Geometry and Infill Patterns
#
#                                              content
# 0  Large Scale Gantry FDM/Router\n\n             ...
# 1  Fasteners\n\n                    \n           ...
# 2  FDM Materials\n\n                    \n       ...
# 3  Frame Geometry and Infill Patterns\n\n        ...
# 4  One of the things we first talked about was po...

# %%
df2.head()
# Out:
#                 name                              time  \
# 0        idesigncars  2014-10-20T21:46:27.759440+00:00
# 1           nfreytag         2014-10-20T20:28:18+00:00
# 2            rambone  2014-11-06T02:05:33.780373+00:00
# 3            rambone  2014-11-06T20:48:28.216903+00:00
# 4  Huynh_ngoc_lan600  2014-11-07T11:36:06.644449+00:00
#
#                      action                    activity  \
# 0    commented on the topic  ...And the Winners are...!
# 1          added a blogpost                        0000
# 2  added a personal-project                        0000
# 3            updated design                        0000
# 4            updated design                        0000
#
#                                              content
# 0                       @karen_dustry.... Sigh.....
# 1  The Local Motors Sports Car Platform has been ...
# 2                              common ducati already
# 3            ideas on the MODSTER modular sports car
# 4                                      S-400 concept

# %%
df3.head()
# Out:
#            Fuser                  date                   action  \
# 0  benzo_ferrari  2008-05-20T20:23:08Z  commented on the  topic
# 1    localmotors  2008-05-20T20:24:26Z  commented on the  topic
# 2        deuxfov  2008-05-20T20:24:26Z  commented on the  topic
# 3        deuxfov  2008-05-20T20:24:26Z          created a topic
# 4         filski  2008-05-20T20:56:30Z  commented on the  topic
#
#                                                  uri  \
# 0  https://cocreate.localmotors.com/discussion/to...
# 1  https://cocreate.localmotors.com/discussion/to...
# 2  https://cocreate.localmotors.com/discussion/to...
# 3                              x1 mid-engine concept
# 4  https://cocreate.localmotors.com/discussion/to...
#
#                                              content InReplyTo Topic编号
# 0  This checkup was approved on Tuesday May 20th ...       NaN  42092/
# 1  This checkup was approved on Tuesday May 20th ...       NaN  42092/
# 2                          x1 mid-engine suv concept       NaN  42092/
# 3                              x1 mid-engine concept       NaN  42092/
# 4  did BMW know about you before they designed th...       NaN  42092/

# %% [markdown]
# # 1. 统计每个项目下的用户人数

# %%
p1 = df1['user'].value_counts().shape[0]
p2 = df2['name'].value_counts().shape[0]
p3 = df3['Fuser'].value_counts().shape[0]
pd.DataFrame([[p1,p2,p3]], columns=["3D-printed", "LM-SF", "RF"])
# Out:
#    3D-printed  LM-SF   RF
# 0         336    703  332

# %% [markdown]
# # 2. 以一个月为单位时长,统计每月参与项目人数，并画出折线图

# %%
df1["date"] = pd.to_datetime(df1["date"])
df1 = df1.set_index("date")

df2["time"] = pd.to_datetime(df2["time"])
df2 = df2.set_index("time")

df3["date"] = pd.to_datetime(df3["date"])
df3 = df3.set_index("date")

# %%
df1_month = df1.to_period('M')
df1_month_user = df1_month.groupby(df1_month.index)["user"].count()

df2_month = df2.to_period('M')
df2_month_user = df2_month.groupby(df2_month.index)["name"].count()

df3_month = df3.to_period('M')
df3_month_user = df3_month.groupby(df3_month.index)["Fuser"].count()
# Out:
# /Users/nick/.venv/ML-training/lib/python3.6/site-packages/pandas/core/arrays/datetimes.py:1172: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   "will drop timezone information.", UserWarning)

# %%
df1_month_user.plot(title='3D-printed')

# %%
df2_month_user.plot(title='LM-SF')

# %%
df3_month_user.plot(title='RF')

# %% [markdown]
# # 3. 统计action的类别，每个类别action数量（饼图），随时间分布折线图，每个用户action随时间的分布

# %%
df1_action = pd.DataFrame(df1['action'].value_counts().rename("3D-printed action count", inplace = True))
# action的类别
df1_action
# Out:
#                            3D-printed action count
# commented on the entry                        2919
# commented on the topic                         545
# added a entry to                               206
# commented on the blogpost                      109
# created a topic                                 47
# commented on the idea                           17
# added a idea to                                 12
# added a blogpost to                              2
# added a file to                                  2

# %%
# action数量的饼图
df1_action.plot.pie(figsize=(8, 8), subplots=True, autopct="%.2f%%",
                    legend=True, title="3D-printed action count", labeldistance=1.2,pctdistance=1.1)
plt.legend(loc=[1, 1])

# %%
# action随时间分布图
df1_day = df1.to_period('D')
df1_day
df1_day_user = df1_day.groupby([df1_day.index])["action"].value_counts()
df1_day_user.unstack(level = 1).plot(figsize=(12, 6), title="3D-printed action 时间分布图")

# %%
# 用户下的action随机时间分布
df1_day.groupby([df1_day.index, "action"])["user"].value_counts()
# Out:
# date        action                     user
# 2014-01-14  created a topic            AlexFi                   1
# 2014-01-17  commented on the topic     Aurel.                   3
#                                        Jearle                   2
#             created a topic            Jearle                   3
#                                        Aurel.                   1
# 2014-01-22  commented on the topic     Jearle                   1
# 2014-01-24  commented on the topic     burhop                   3
#                                        jrogers                  3
#                                        AlexFi                   1
#                                        nllanos                  1
#             created a topic            jrogers                  1
# 2014-01-26  commented on the topic     MattJackson              2
#                                        RaMansell                1
# 2014-01-27  commented on the topic     Jearle                   5
#                                        RaMansell                1
#                                        nllanos                  1
# 2014-01-28  commented on the topic     burhop                   1
#                                        nllanos                  1
#             created a topic            AnonymousPerson          1
# 2014-01-29  commented on the idea      Jearle                   1
#             commented on the topic     nllanos                  4
#                                        burhop                   2
#                                        Gibus                    1
#                                        Jearle                   1
#                                        MattJackson              1
#             created a topic            LM-Kate                  1
#                                        nllanos                  1
# 2014-01-30  commented on the topic     andrey327a               2
#                                        stratus_revo             2
#                                        JakeFerguson             1
#                                                                ..
# 2015-02-01  commented on the topic     dmhpeters                1
# 2015-02-02  commented on the topic     MattJackson              1
# 2015-02-03  commented on the blogpost  rahulbhadani             1
#             commented on the topic     dmhpeters                1
# 2015-02-06  commented on the blogpost  pleasecanyounotspamme    1
# 2015-02-11  commented on the topic     Tony_Rivera              1
#                                        driha                    1
# 2015-02-12  commented on the topic     Tony_Rivera              1
# 2015-02-25  commented on the entry     sabatineyonye            1
# 2015-03-13  commented on the topic     Tony_Rivera              1
# 2015-03-19  commented on the topic     Jearle                   1
#                                        Tony_Rivera              1
# 2015-04-14  commented on the entry     crzylegz56               1
# 2015-04-22  commented on the entry     Zeast                    1
# 2015-04-29  commented on the entry     al-fasel                 1
# 2015-05-06  commented on the blogpost  victoriacrockett         1
# 2015-05-13  commented on the topic     WadeWilliams             1
#                                        designman4               1
#                                        wakeboardmn              1
#             created a topic            wakeboardmn              1
# 2015-05-15  added a blogpost to        BWilkins                 1
#             commented on the topic     mgunson-LM               1
# 2015-05-16  commented on the topic     wakeboardmn              2
#                                        jrogers                  1
#                                        mobotiq                  1
# 2015-05-18  commented on the blogpost  burhop                   1
#             commented on the topic     driha                    1
#                                        wakeboardmn              1
# 2015-05-19  commented on the blogpost  burhop                   1
#                                        jrogers                  1
# Name: user, Length: 1696, dtype: int64

# %%
df2_action = pd.DataFrame(df2['action'].value_counts().rename("LM-SF action count", inplace = True))
# action的类别
df2_action
# Out:
#                                    LM-SF action count
# commented on the entry                           5859
# commented on the topic                           1640
# updated entry in                                 1077
# added a idea to                                   349
# commented on the idea                             300
# commented on the blogpost                         253
# added a entry to                                  202
# added a file to                                    76
# created a topic                                    36
# updated idea in                                    18
# added a blogpost to                                 6
# commented on the personal-project                   5
# updated design                                      2
# added a brainstorm to                               2
# added a personal-project                            1
# commented on the design                             1
# updated brainstorm in                               1
# added a blogpost                                    1
# updated blogpost in                                 1

# %%
# action数量的饼图
df2_action.plot.pie(figsize=(8, 8), subplots=True, autopct="%.2f%%",
                    legend=True, title="LM-SF action count", labeldistance=1.2,pctdistance=1.1)
plt.legend(loc=[1, 1])

# %%
# action随时间分布图
df2_day = df2.to_period('D')
df2_day_user = df2_day.groupby([df2_day.index])["action"].value_counts()
df2_day_user.unstack(level = 1).plot(figsize=(12, 6), title="LM-SF action 时间分布图")

# %%
# 用户下的action随机时间分布
df2_day.groupby([df2_day.index, "action"])["name"].value_counts()
# Out:
# time        action                     name
# 2014-07-01  commented on the blogpost  MattJackson            6
#                                        dirk                   2
#                                        zz383mero              2
#                                        Flyball                1
#                                        MicheleAbbate          1
#                                        RaMansell              1
#                                        Tony_Rivera            1
#                                        gferguson              1
#                                        ivan.pankratov         1
#                                        jmullens               1
#                                        jonathon.klein         1
#                                        jorge.mma.moreira      1
#                                        nathaniel.s.green      1
#             commented on the topic     MattJackson           14
#                                        flameskyefox           6
#                                        teamkeehn              5
#                                        jason.s.pedersen       4
#                                        ryanator12             3
#                                        Aurel.                 2
#                                        DrPirateface           2
#                                        MicheleAbbate          2
#                                        bulletroll             2
#                                        gferguson              2
#                                        lee-herge              2
#                                        nmalinoski             2
#                                        yinster                2
#                                        BluePhoenix            1
#                                        El_jefe                1
#                                        Flyball                1
#                                        Krynn                  1
#                                                              ..
# 2015-10-09  commented on the blogpost  NemoDesigns            1
#                                        TaurusNut              1
#                                        dabo                   1
# 2015-10-10  commented on the blogpost  NemoDesigns            1
# 2015-10-12  commented on the blogpost  dabo                   1
# 2015-10-13  commented on the blogpost  NemoDesigns            1
# 2015-10-14  commented on the blogpost  NemoDesigns            3
#                                        TaurusNut              3
#             commented on the topic     rambone                1
# 2015-10-15  commented on the blogpost  TaurusNut              1
# 2015-10-19  commented on the blogpost  idesigncars            1
# 2015-10-20  commented on the topic     blessingrugara         1
# 2015-10-23  added a idea to            warwicksharp           1
# 2015-11-08  commented on the topic     davitsandrosyan        1
# 2015-11-09  commented on the topic     MattJackson            1
# 2015-11-10  commented on the topic     byronyoung             1
# 2015-11-18  commented on the topic     cbotos                 1
# 2015-11-20  added a idea to            designman4             1
# 2015-11-21  commented on the blogpost  mikegsrcar             2
# 2015-12-14  commented on the entry     jamzwong               1
# 2015-12-18  added a idea to            NemoDesigns            1
# 2015-12-29  added a idea to            jacobsharvey           1
#             commented on the idea      jacobsharvey           1
# 2016-01-22  added a idea to            StreetRoadandTrack     1
# 2016-02-04  commented on the entry     Madjammer              1
# 2016-03-31  commented on the topic     austin_burgenstock     2
#                                        NemoDesigns            1
#                                        sagdiyev               1
# 2016-04-01  commented on the topic     austin_burgenstock     1
# 2016-04-06  commented on the entry     johndouglas            1
# Name: name, Length: 4291, dtype: int64

# %%
df3_action = pd.DataFrame(df3['action'].value_counts().rename("RF action count", inplace = True))
# action的类别
df3_action
# Out:
#                          RF action count
# commented on the  topic             2237
# commented on the entry               265
# created a topic                      258
# commented on the idea                126
# added a blogpost                      66
# commented on the topic                58
# added a idea to                       37
# added a entry to                      34
# added a design                        15
# commented on the design                7

# %%
# action数量的饼图
df3_action.plot.pie(figsize=(8, 8), subplots=True, autopct="%.2f%%",
                    legend=True, title="LM-SF action count", labeldistance=1.2,pctdistance=1.1)
plt.legend(loc=[1, 1])

# %%
# action随时间分布图
df3_day = df3.to_period('D')
df3_day_user = df3_day.groupby([df3_day.index])["action"].value_counts()
df3_day_user.unstack(level = 1).plot(figsize=(12, 6), title="RF action 时间分布图")

# %%
# 用户下的action随机时间分布
df3_day.groupby([df3_day.index, "action"])["Fuser"].value_counts()
# Out:
# date        action                   Fuser
# 2008-05-20  commented on the  topic  jrogers                 3
#                                      benzo_ferrari           2
#                                      deuxfov                 1
#                                      filski                  1
#                                      localmotors             1
#                                      tthomas                 1
#             created a topic          deuxfov                 1
# 2008-05-21  commented on the  topic  benzo_ferrari           4
#                                      jrogers                 2
#                                      Canay                   1
#                                      Palethorpe              1
#                                      deuxfov                 1
#                                      rizawerks               1
# 2008-05-22  commented on the  topic  Ben-J                   1
#                                      Palethorpe              1
#                                      WiKID                   1
#                                      benzo_ferrari           1
#                                      candyrod                1
#                                      jrogers                 1
# 2008-05-23  commented on the  topic  jrogers                 4
#                                      Brianm                  2
#                                      sheriffdesignstudio     1
# 2008-05-24  commented on the  topic  Me2                     1
#                                      leonharddesign          1
# 2008-05-27  commented on the  topic  Ari                     1
#                                      benzo_ferrari           1
#                                      deuxfov                 1
# 2008-05-29  commented on the  topic  KarinO                  1
# 2008-05-30  commented on the  topic  Brianm                  2
#                                      deuxfov                 2
#                                                             ..
# 2015-09-25  added a design           nilsh                   1
#             commented on the design  rf61                    1
# 2015-10-01  added a design           nilsh                   1
# 2015-10-03  commented on the design  rf61                    1
# 2015-10-09  added a design           nilsh                   1
#             commented on the design  nilsh                   1
# 2015-10-13  commented on the design  AlaricEgli              1
# 2015-10-16  added a design           nilsh                   1
#             commented on the design  nilsh                   1
# 2015-10-23  added a design           nilsh                   1
# 2015-10-30  added a design           nilsh                   1
# 2015-11-20  added a design           nilsh                   1
#             commented on the design  nilsh                   2
# 2015-11-30  added a design           nilsh                   1
# 2015-12-02  commented on the idea    hellswung               2
# 2015-12-06  commented on the idea    einuesse                2
# 2015-12-07  commented on the idea    hellswung               2
# 2016-05-10  added a idea to          djcamilleri02           1
# 2016-05-11  added a idea to          soccermo2000            1
# 2016-05-23  commented on the idea    jaurigue                1
# 2016-05-31  added a idea to          petermurray             1
#             commented on the idea    petermurray             1
# 2016-07-08  added a idea to          stefansteenkamp         1
# 2016-08-08  commented on the idea    hnackley                1
# 2016-08-18  commented on the idea    dkpinho                 1
# 2016-08-31  commented on the  topic  Funcars_For_Everyday    1
#             commented on the idea    blocklori               1
#             created a topic          Funcars_For_Everyday    1
# 2016-09-01  added a idea to          soccermo2000            1
# 2016-09-03  commented on the  topic  1406841095              2
# Name: Fuser, Length: 1973, dtype: int64

# %% [markdown]
# # 4. activity主题的数量，随时间分布（折线图）

# %%
# activity的数量
p1 = df1['activity'].value_counts().shape[0]
p2 = df2['activity'].value_counts().shape[0]
pd.DataFrame([[p1,p2]], columns=["3D-printed", "LM-SF"])
# Out:
#    3D-printed  LM-SF
# 0         300    485

# %%
# 主题数随时间变化（累积）
df1_day = df1.to_period('D')
df1_day_user = df1_day.groupby(df1_day.index)["activity"].count()
df1_day_user.cumsum().plot(title='3D-printed activity 随时间的变化')

# %%
# 主题数随时间变化（累积）
df2_day = df2.to_period('D')
df2_day_user = df2_day.groupby(df2_day.index)["activity"].count()
df2_day_user.cumsum().plot(title='LM-SF activity 随时间的变化')

# %% [markdown]
# # 5. 以activity为索引，建立用户关系图（网络图）

# %%
# 先统计所有的action
a = set(df1['action'].value_counts().index)
b = set(df2['action'].value_counts().index)
c = set(df3['action'].value_counts().index)
all_action = list(a | b | c)
all_action
# Out:
# ['commented on the design',
#  'commented on the  topic',
#  'added a file to',
#  'commented on the entry',
#  'created a topic',
#  'added a design',
#  'updated idea in',
#  'updated brainstorm in',
#  'commented on the blogpost',
#  'updated blogpost in',
#  'added a idea to',
#  'commented on the personal-project',
#  'added a entry to',
#  'commented on the idea',
#  'added a brainstorm to',
#  'updated design',
#  'commented on the topic',
#  'added a blogpost to',
#  'added a personal-project',
#  'updated entry in',
#  'added a blogpost']

# %%
# 创建帖子
build_action = []
for i in all_action:
    if i.startswith("created"):
        build_action.append(i)
build_action
# Out:
# ['created a topic']

# %%
# 评论动作帖子
not_build_action = []
for i in all_action:
    if not i.startswith("created"):
        not_build_action.append(i)
not_build_action
# Out:
# ['commented on the design',
#  'commented on the  topic',
#  'added a file to',
#  'commented on the entry',
#  'added a design',
#  'updated idea in',
#  'updated brainstorm in',
#  'commented on the blogpost',
#  'updated blogpost in',
#  'added a idea to',
#  'commented on the personal-project',
#  'added a entry to',
#  'commented on the idea',
#  'added a brainstorm to',
#  'updated design',
#  'commented on the topic',
#  'added a blogpost to',
#  'added a personal-project',
#  'updated entry in',
#  'added a blogpost']

# %%
df1_activity = pd.read_excel(p1_path)
df1_activity = df1_activity.set_index("activity")
df2_activity = pd.read_excel(p2_path)
df2_activity = df2_activity.set_index("activity")

# %%
# 项目一 3Dprinter
df1_activity_create = df1_activity[df1_activity['action'].isin(build_action)][["user"]]
df1_activity_create_map = dict()
for index, value in enumerate(df1_activity_create.user):
    df1_activity_create_map[df1_activity_create.index[index]] = value
    
def map_dict(v):
    try:
        return df1_activity_create_map[v]
    except:
        return np.NaN

df1_activity["action_to"] = df1_activity.index
df1_activity["action_to"] = df1_activity["action_to"].apply(map_dict)

df1_activity["is_add"] = df1_activity["action"].apply(lambda x:1 if x in build_action else 0)

df1_activity.head()
# Out:
#                                       user reuser                       date  \
# activity
# Large Scale Gantry FDM/Router       AlexFi    NaN  2014-01-14T17:11:00+00:00
# Fasteners                           Jearle    NaN  2014-01-17T16:17:33+00:00
# FDM Materials                       Jearle    NaN  2014-01-17T16:24:22+00:00
# Frame Geometry and Infill Patterns  Jearle    NaN  2014-01-17T16:30:21+00:00
# Frame Geometry and Infill Patterns  Jearle    NaN  2014-01-17T16:36:37+00:00
#
#                                                     action  \
# activity
# Large Scale Gantry FDM/Router              created a topic
# Fasteners                                  created a topic
# FDM Materials                              created a topic
# Frame Geometry and Infill Patterns         created a topic
# Frame Geometry and Infill Patterns  commented on the topic
#
#                                                                               content  \
# activity
# Large Scale Gantry FDM/Router       Large Scale Gantry FDM/Router\n\n             ...
# Fasteners                           Fasteners\n\n                    \n           ...
# FDM Materials                       FDM Materials\n\n                    \n       ...
# Frame Geometry and Infill Patterns  Frame Geometry and Infill Patterns\n\n        ...
# Frame Geometry and Infill Patterns  One of the things we first talked about was po...
#
#                                    action_to  is_add
# activity
# Large Scale Gantry FDM/Router         AlexFi       1
# Fasteners                             Jearle       1
# FDM Materials                         Jearle       1
# Frame Geometry and Infill Patterns    Jearle       1
# Frame Geometry and Infill Patterns    Jearle       0

# %%
print(df1_activity.shape)
df1_activity_na = df1_activity.dropna()
print(df1_activity_na.shape)
df1_activity_na[["user", "action_to"]].head(10)
# Out:
# (3859, 7)
# (104, 7)
#                                          user    action_to
# activity
# General Challenge Discussion  vasilatos_ianis  idesigncars
# General Challenge Discussion      idesigncars  idesigncars
# General Challenge Discussion      idesigncars  idesigncars
# General Challenge Discussion      idesigncars  idesigncars
# General Challenge Discussion      idesigncars  idesigncars
# General Challenge Discussion      idesigncars  idesigncars
# General Challenge Discussion         Dodo_101  idesigncars
# General Challenge Discussion           burhop  idesigncars
# General Challenge Discussion         Dodo_101  idesigncars
# General Challenge Discussion         Dodo_101  idesigncars

# %%
G = nx.DiGraph()
G.add_edges_from(df1_activity_na[["user", "action_to"]].values)
nx.draw(G, with_labels=True)
plt.show()

# %%
# 项目二 LS
df2_activity_create = df2_activity[df2_activity['action'].isin(build_action)][["name"]]
df2_activity_create_map = dict()
for index, value in enumerate(df2_activity_create.name):
    df2_activity_create_map[df2_activity_create.index[index]] = value
    
def map_dict(v):
    try:
        return df2_activity_create_map[v]
    except:
        return np.NaN

df2_activity["action_to"] = df2_activity.index
df2_activity["action_to"] = df2_activity["action_to"].apply(map_dict)

df2_activity["is_add"] = df2_activity["action"].apply(lambda x:1 if x in build_action else 0)

df2_activity.head()
# Out:
#                                          name  \
# activity
# ...And the Winners are...!        idesigncars
# 0000                                 nfreytag
# 0000                                  rambone
# 0000                                  rambone
# 0000                        Huynh_ngoc_lan600
#
#                                                         time  \
# activity
# ...And the Winners are...!  2014-10-20T21:46:27.759440+00:00
# 0000                               2014-10-20T20:28:18+00:00
# 0000                        2014-11-06T02:05:33.780373+00:00
# 0000                        2014-11-06T20:48:28.216903+00:00
# 0000                        2014-11-07T11:36:06.644449+00:00
#
#                                               action  \
# activity
# ...And the Winners are...!    commented on the topic
# 0000                                added a blogpost
# 0000                        added a personal-project
# 0000                                  updated design
# 0000                                  updated design
#
#                                                                       content  \
# activity
# ...And the Winners are...!                       @karen_dustry.... Sigh.....
# 0000                        The Local Motors Sports Car Platform has been ...
# 0000                                                    common ducati already
# 0000                                  ideas on the MODSTER modular sports car
# 0000                                                            S-400 concept
#
#                            action_to  is_add
# activity
# ...And the Winners are...!       NaN       0
# 0000                             NaN       0
# 0000                             NaN       0
# 0000                             NaN       0
# 0000                             NaN       0

# %%
print(df2_activity.shape)
df2_activity_na = df2_activity.dropna()
print(df2_activity_na.shape)
df2_activity_na[["name", "action_to"]].head(10)
# Out:
# (9830, 6)
# (1471, 6)
#                                                             name  \
# activity
# 8.8s no weight and a terrifyingly fun right pedal   aronethridge
# Aero Discussion                                    MicheleAbbate
# Aero Discussion                                    MicheleAbbate
# Aero Discussion                                      idesigncars
# Aero Discussion                                    MicheleAbbate
# Aero Discussion                                      MattJackson
# Aero Discussion                                      idesigncars
# Aero Discussion                                    MicheleAbbate
# Aero Discussion                                      MattJackson
# Are some designs looking very similar?                  papagomp
#
#                                                        action_to
# activity
# 8.8s no weight and a terrifyingly fun right pedal   aronethridge
# Aero Discussion                                    MicheleAbbate
# Aero Discussion                                    MicheleAbbate
# Aero Discussion                                    MicheleAbbate
# Aero Discussion                                    MicheleAbbate
# Aero Discussion                                    MicheleAbbate
# Aero Discussion                                    MicheleAbbate
# Aero Discussion                                    MicheleAbbate
# Aero Discussion                                    MicheleAbbate
# Are some designs looking very similar?                  papagomp

# %%
G = nx.DiGraph()
G.add_edges_from(df2_activity_na[["name", "action_to"]].values)
nx.draw(G, with_labels=True)
plt.show()

# %% [markdown]
# # 6. 统计每个项目下用户的出度（评论别人，发帖），入度（被评论）

# %%
# 对这张表来说，user是出度，action_to是入度
df1_activity_user = df1_activity[["user", "action_to"]]
df1_activity_user.head()
# Out:
#                                       user action_to
# activity
# Large Scale Gantry FDM/Router       AlexFi    AlexFi
# Fasteners                           Jearle    Jearle
# FDM Materials                       Jearle    Jearle
# Frame Geometry and Infill Patterns  Jearle    Jearle
# Frame Geometry and Infill Patterns  Jearle    Jearle

# %%
# 3Dprinter的出度数量
df1_activity_user_to = pd.DataFrame(df1_activity_user.groupby("user")["user"].count())
# 3Dprinter的入度数量
df1_activity_user_in = pd.DataFrame(df1_activity_user.groupby("action_to")["action_to"].count())
df1_action = df1_activity_user_to.join(df1_activity_user_in).fillna(0)
df1_action.columns = ["出度", "入度"]
df1_action.head(8)
# Out:
#              出度   入度
# user
#  j.chambon    1  0.0
# 0             1  0.0
# 3DPrintWise   1  0.0
# 7cantlose     1  0.0
# AMR          12  0.0
# Adan          8  0.0
# AirGar        1  0.0
# AlexFi        4  5.0

# %%
# 对这张表来说，user是出度，action_to是入度
df2_activity_user = df2_activity[["name", "action_to"]]
df2_activity_user.head()
# Out:
#                                          name action_to
# activity
# ...And the Winners are...!        idesigncars       NaN
# 0000                                 nfreytag       NaN
# 0000                                  rambone       NaN
# 0000                                  rambone       NaN
# 0000                        Huynh_ngoc_lan600       NaN

# %%
# LS的出度数量
df2_activity_user_to = pd.DataFrame(df2_activity_user.groupby("name")["name"].count())
# LS的入度数量
df2_activity_user_in = pd.DataFrame(df2_activity_user.groupby("action_to")["action_to"].count())
df2_action = df2_activity_user_to.join(df2_activity_user_in).fillna(0)
df2_action.columns = ["出度", "入度"]
df2_action.head(8)
# Out:
#                 出度   入度
# name
# A.James         15  0.0
# AC3R1GG1NS       3  0.0
# APP              1  0.0
# AdamKeiser       2  0.0
# Adan            57  0.0
# Afongartdesign  19  0.0
# AlexFi           2  0.0
# Alireza          3  0.0

# %% [markdown]
# # 8. 统计每个主题下用户的出度与入度（同时统计按时间分布）

# %%
df1_activity.head()
# Out:
#                                       user reuser                       date  \
# activity
# Large Scale Gantry FDM/Router       AlexFi    NaN  2014-01-14T17:11:00+00:00
# Fasteners                           Jearle    NaN  2014-01-17T16:17:33+00:00
# FDM Materials                       Jearle    NaN  2014-01-17T16:24:22+00:00
# Frame Geometry and Infill Patterns  Jearle    NaN  2014-01-17T16:30:21+00:00
# Frame Geometry and Infill Patterns  Jearle    NaN  2014-01-17T16:36:37+00:00
#
#                                                     action  \
# activity
# Large Scale Gantry FDM/Router              created a topic
# Fasteners                                  created a topic
# FDM Materials                              created a topic
# Frame Geometry and Infill Patterns         created a topic
# Frame Geometry and Infill Patterns  commented on the topic
#
#                                                                               content  \
# activity
# Large Scale Gantry FDM/Router       Large Scale Gantry FDM/Router\n\n             ...
# Fasteners                           Fasteners\n\n                    \n           ...
# FDM Materials                       FDM Materials\n\n                    \n       ...
# Frame Geometry and Infill Patterns  Frame Geometry and Infill Patterns\n\n        ...
# Frame Geometry and Infill Patterns  One of the things we first talked about was po...
#
#                                    action_to  is_add
# activity
# Large Scale Gantry FDM/Router         AlexFi       1
# Fasteners                             Jearle       1
# FDM Materials                         Jearle       1
# Frame Geometry and Infill Patterns    Jearle       1
# Frame Geometry and Infill Patterns    Jearle       0

# %%
# 3Dprinter 按照主题的出度数量
df1_activity.groupby([df1_activity.index])["user"].value_counts()
# Out:
# activity                            user
# "E130"                              JannS                   4
#                                     NemoDesigns             2
#                                     braunarsch              1
#                                     chavito                 1
#                                     nick_ricci              1
# "Nemi Bone" 3D Printed Car          BMWZ8                   9
#                                     NemoDesigns             3
#                                     GTR                     2
#                                     Alireza                 1
#                                     Aurel.                  1
#                                     M.Monfared              1
#                                     Mr-Design               1
#                                     Qo-Di                   1
#                                     braunarsch              1
#                                     cutesamuel004           1
#                                     jawahery                1
#                                     lulu                    1
#                                     mahdighaedi.d           1
#                                     marian_cilibeanu        1
#                                     mikeruiz568             1
#                                     nllanos                 1
#                                     pghaedrahmat            1
#                                     romanbasti              1
#                                     siavashjafarijozani     1
#                                     spacerodsal             1
# .5CR 3D Print                       NemoDesigns             1
#                                     braunarsch              1
#                                     jononeal                1
# 3D Print Your Own Miniature Strati  nllanos                 2
#                                     7cantlose               1
#                                                            ..
# shurik's entry                      vasilatos_ianis         1
# sprin3d                             buCARsa                20
#                                     NemoDesigns             4
#                                     braunarsch              3
#                                     chavito                 3
#                                     gabi_hantig             2
#                                     marian_cilibeanu        2
#                                     nllanos                 2
#                                     spacerodsal             2
#                                     vasilatos_ianis         2
#                                     GTR                     1
#                                     InfernoCreations        1
#                                     Lude                    1
#                                     jrogers                 1
#                                     spoon334                1
# status "employee"                   thdudesign              1
#                                     vasilatos_ianis         1
# the 3deee printed car               NemoDesigns             1
# unico                               Karen_Dustry            1
#                                     NemoDesigns             1
# voting grades                       romanbasti              3
#                                     NemoDesigns             1
#                                     Qo-Di                   1
#                                     vasilatos_ianis         1
# wheels for renders                  Deivid                  2
#                                     vasilatos_ianis         2
#                                     gery_v_w                1
# why not faster with shorter range?  awest                   1
# ​45 ° overhang                      nllanos                 1
#                                     viljami.raisanen        1
# Name: user, Length: 2051, dtype: int64

# %%
# 3Dprinter 按照主题的入度数量
df1_activity.groupby([df1_activity.index])["action_to"].value_counts()
# Out:
# activity                                      action_to
# 3D printer working area                       romanogaspari         3
# 3D printing a house                           Helpp                 1
# 3DPCX                                         gabi_hantig         176
# Advanced Materials                            burhop                7
# Car Assembly Updates                          awest                 5
# Design for Customization                      awest                 3
# Dunkleostra                                   braunarsch           14
# Edit your entry?                              Botzen                2
# Electric powertrain                           nllanos              26
# Excited about Hondas new engine?              patron_vectras        3
# FDM Materials                                 Jearle               29
# FIRST robotics chassis                        jrogers               7
# Fasteners                                     Jearle               20
# Frame Geometry and Infill Patterns            Jearle               31
# Future Possibilities                          Jearle                8
# General Challenge Discussion                  idesigncars         164
# I understand the concept but why?             AnonymousPerson       6
# IMTS Stand                                    Vincent               2
# Is this car open source?                      heath                 4
# LM Strati Detroit                             nllanos               5
# Large Scale Gantry FDM/Router                 AlexFi                5
# Life of the Detroit Auto Show Strati          wakeboardmn          11
# Mold use                                      chavito               4
# Ownership of Intellectual Property?           kerry.manning         1
# PLA & Carbon Fiber Used In 3D Printing        LM-Kate              14
# PLEASE HELP?...                               spacerodsal           7
# Printable Models                              burhop                8
# Printing a cube/cuboid                        prashton              4
# Printing the Car                              Jearle               52
# Recent Updates                                sandesh_rai           1
# State of the art and 3D printing inspiration  Zeast                66
# To Nemo - Deadline                            Vincent               7
# Twizy powertrain tuning                       waffenschmiedeat      3
# Update On DDM Car From ORNL - February 2014   LM-Kate               1
# Validation mistakes                           Karen_Dustry         31
# Voting results?                               ernesto_ferri        27
# Where is the CAD model?                       sachlenesingh         2
# assembling the car                            romanogaspari         2
# inspiration                                   justinf               2
# status "employee"                             thdudesign            2
# voting grades                                 romanbasti            6
# wheels for renders                            gery_v_w              5
# ​45 ° overhang                                viljami.raisanen      2
# Name: action_to, dtype: int64

# %%
# LS 按照主题的出度数量
df2_activity.groupby([df2_activity.index])["name"].value_counts()
# Out:
# activity                                    name
# ...And the Winners are...!                  idesigncars           1
# 0000                                        rambone               2
#                                             Huynh_ngoc_lan600     1
#                                             nfreytag              1
# 1st doodle                                  Aurel.                1
#                                             Franze                1
#                                             NemoDesigns           1
#                                             designman4            1
#                                             idesigncars           1
#                                             papagomp              1
# 2-BoXXer                                    Bearon                1
#                                             NemoDesigns           1
# 20140820 LC SCPC Matteo Gentile Proposals.  mark2257              2
#                                             Miletic_Design        1
#                                             NemoDesigns           1
#                                             SEIZMICdesign         1
#                                             Samyar                1
#                                             Tony_Rivera           1
#                                             chavito               1
#                                             goat1750              1
#                                             lulu                  1
#                                             mattegentile          1
#                                             papagomp              1
#                                             sixten                1
#                                             staylor               1
# 2FUN                                        Lude                  1
#                                             MattJackson           1
#                                             braunarsch            1
#                                             plux                  1
# 30-30                                       fam_jaes             11
#                                                                  ..
# voltage                                     TURISMO               4
#                                             chavito               4
#                                             MattJackson           2
#                                             braunarsch            2
#                                             gabi_hantig           2
#                                             goat1750              2
#                                             papagomp              2
#                                             sidewinder            2
#                                             Adan                  1
#                                             Franze                1
#                                             Indianmick            1
#                                             JSmith                1
#                                             KRVZ                  1
#                                             Lude                  1
#                                             PE4                   1
#                                             SEIZMICdesign         1
#                                             blessingrugara        1
#                                             extreme               1
#                                             humming_rob           1
#                                             idesigncars           1
#                                             jelilebrizuela        1
#                                             jmullens              1
#                                             lulu                  1
#                                             mreiter               1
#                                             mycristian            1
#                                             plux                  1
#                                             sixten                1
#                                             spoon334              1
#                                             yasser4008            1
# wind shield-jets                            marcelinoseko         1
# Name: name, Length: 4199, dtype: int64

# %%
# LS 按照主题的入度数量
df2_activity.groupby([df2_activity.index])["action_to"].value_counts()
# Out:
# activity                                           action_to
# 8.8s no weight and a terrifyingly fun right pedal  aronethridge          1
# Aero Discussion                                    MicheleAbbate         8
# Are some designs looking very similar?             papagomp              3
# AutoCAD drawings                                   PKDow                 3
# Body Refinement Stage 1                            NemoDesigns         226
# Body Refinement Stage 2                            NemoDesigns          67
# Body production                                    NemoDesigns          30
# Body/Aerodynamics                                  Rhein                26
# Brakes, Clutch, Hydraulics                         bse50                 7
# Chassis                                            MattJackson         148
# Chassis Design Discussion                          MattJackson          34
# Computational Fluid Dynamics                       slimjim8201          67
# Extending the challange for a week                 crisiiicube          21
# Fifth Scale model                                  MattJackson           5
# General                                            MattJackson          65
# How to start an entry?                             Samyar                3
# Ignition Kit/ Asset Updates                        idesigncars          18
# Interior                                           frostmartinez       135
# Is the Winner know to anyone?                      Blue-Jay              5
# Offer Maya platform models  pretty please          towerindustries       2
# Onshape Test                                       MattJackson          18
# Packaging Benchmark                                Aurel.               28
# Powertrain                                         MattJackson         288
# Project Influence Scores                           MattJackson          16
# Put a top on it....                                selfsettle            2
# Seat Belts                                         jason.s.pedersen      5
# Suspension                                         MattJackson         132
# The 3 winners of the Sports Car Challenge are​...  Blue-Jay             13
# Versatile Frame?                                   Cristian_F            2
# Voting!                                            kerc                 90
# Whiskey Tango Foxtrot?                             MikahB                2
# for 3ds max users                                  PE4                   2
# general                                            whitgatline           5
# information                                        designman4            5
# name this car                                      jerrieanne75m         1
# Name: action_to, dtype: int64

# %% [markdown]
# # 9. content分词

# %%
stoplist = [" ", "\n", "\xa0"]
def cut_word(txt):
    return [w for w in jieba.cut(txt) if w not in stoplist]

# %%
# 3Dprinter
df1 = df1.dropna()
df1["cut"] = df1["content"].apply(cut_word)
df1.head()
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/wq/03z5h7352159jp2k5p83ts500000gn/T/jieba.cache
# Loading model cost 0.767 seconds.
# Prefix dict has been built successfully.
#                                       user    reuser                  action  \
# date
# 2014-04-12 05:05:41+00:00  vasilatos_ianis      iuli  commented on the topic
# 2014-04-12 15:56:25+00:00      idesigncars  spoon334  commented on the topic
# 2014-04-12 15:56:36+00:00      idesigncars  Dodo_101  commented on the topic
# 2014-04-12 15:56:50+00:00      idesigncars      iuli  commented on the topic
# 2014-04-12 15:57:39+00:00      idesigncars     Paulo  commented on the topic
#
#                                                activity  \
# date
# 2014-04-12 05:05:41+00:00  General Challenge Discussion
# 2014-04-12 15:56:25+00:00  General Challenge Discussion
# 2014-04-12 15:56:36+00:00  General Challenge Discussion
# 2014-04-12 15:56:50+00:00  General Challenge Discussion
# 2014-04-12 15:57:39+00:00  General Challenge Discussion
#
#                                                                      content  \
# date
# 2014-04-12 05:05:41+00:00  and you did! \n\n                    View topi...
# 2014-04-12 15:56:25+00:00  This is noted. C'mon Spoon, you only have 12 h...
# 2014-04-12 15:56:36+00:00  Nope-- see reply to Spoon\n\n                 ...
# 2014-04-12 15:56:50+00:00  Thats probably it. \n\n                    Vie...
# 2014-04-12 15:57:39+00:00  Paulo, great question. Right now the pinter is...
#
#                                                                          cut
# date
# 2014-04-12 05:05:41+00:00             [and, you, did, !, View, topic, Reply]
# 2014-04-12 15:56:25+00:00  [This, is, noted, ., C, ', mon, Spoon, ,, you,...
# 2014-04-12 15:56:36+00:00  [Nope, --, see, reply, to, Spoon, View, topic,...
# 2014-04-12 15:56:50+00:00       [Thats, probably, it, ., View, topic, Reply]
# 2014-04-12 15:57:39+00:00  [Paulo, ,, great, question, ., Right, now, the...

# %%
# LS
df2 = df2.dropna()
df2["cut"] = df2["content"].apply(cut_word)
df2.head()
# Out:
#                                                name                    action  \
# time
# 2014-10-20 21:46:27.759440+00:00        idesigncars    commented on the topic
# 2014-10-20 20:28:18+00:00                  nfreytag          added a blogpost
# 2014-11-06 02:05:33.780373+00:00            rambone  added a personal-project
# 2014-11-06 20:48:28.216903+00:00            rambone            updated design
# 2014-11-07 11:36:06.644449+00:00  Huynh_ngoc_lan600            updated design
#
#                                                     activity  \
# time
# 2014-10-20 21:46:27.759440+00:00  ...And the Winners are...!
# 2014-10-20 20:28:18+00:00                               0000
# 2014-11-06 02:05:33.780373+00:00                        0000
# 2014-11-06 20:48:28.216903+00:00                        0000
# 2014-11-07 11:36:06.644449+00:00                        0000
#
#                                                                             content  \
# time
# 2014-10-20 21:46:27.759440+00:00                       @karen_dustry.... Sigh.....
# 2014-10-20 20:28:18+00:00         The Local Motors Sports Car Platform has been ...
# 2014-11-06 02:05:33.780373+00:00                              common ducati already
# 2014-11-06 20:48:28.216903+00:00            ideas on the MODSTER modular sports car
# 2014-11-07 11:36:06.644449+00:00                                      S-400 concept
#
#                                                                                 cut
# time
# 2014-10-20 21:46:27.759440+00:00           [@, karen, _, dustry, ...., Sigh, .....]
# 2014-10-20 20:28:18+00:00         [The, Local, Motors, Sports, Car, Platform, ha...
# 2014-11-06 02:05:33.780373+00:00                          [common, ducati, already]
# 2014-11-06 20:48:28.216903+00:00    [ideas, on, the, MODSTER, modular, sports, car]
# 2014-11-07 11:36:06.644449+00:00                               [S, -, 400, concept]

# %%
# RF
df3 = df3.dropna()
df3["cut"] = df3["content"].apply(cut_word)
df3.head()
# Out:
#                                   Fuser                   action  \
# date
# 2012-04-19 23:12:54+00:00  Ellocomotive  commented on the  topic
# 2012-06-11 13:16:39+00:00       moebius  commented on the  topic
# 2013-01-12 20:09:43+00:00   Tony_Rivera  commented on the  topic
# 2013-01-12 20:22:19+00:00     RaMansell  commented on the  topic
# 2013-01-12 21:00:05+00:00     RaMansell  commented on the  topic
#
#                                                                          uri  \
# date
# 2012-04-19 23:12:54+00:00  https://cocreate.localmotors.com/discussion/to...
# 2012-06-11 13:16:39+00:00  https://cocreate.localmotors.com/discussion/to...
# 2013-01-12 20:09:43+00:00  https://cocreate.localmotors.com/discussion/to...
# 2013-01-12 20:22:19+00:00  https://cocreate.localmotors.com/discussion/to...
# 2013-01-12 21:00:05+00:00  https://cocreate.localmotors.com/discussion/to...
#
#                                                                      content  \
# date
# 2012-04-19 23:12:54+00:00  I could do it with Gen 1:D  Of course running ...
# 2012-06-11 13:16:39+00:00  You know I put one of the LED light bars in th...
# 2013-01-12 20:09:43+00:00  Thanks Richard, I would love it if you were ou...
# 2013-01-12 20:22:19+00:00  I remember Buddy Crisp at SEMA showing me the ...
# 2013-01-12 21:00:05+00:00  I did find this today on Youtube.  The Rally F...
#
#                              InReplyTo Topic编号  \
# date
# 2012-04-19 23:12:54+00:00   slick_nick  47857/
# 2012-06-11 13:16:39+00:00     MikeBDFE  47850/
# 2013-01-12 20:09:43+00:00    RaMansell  47870/
# 2013-01-12 20:22:19+00:00    RaMansell  47870/
# 2013-01-12 21:00:05+00:00    RaMansell  47870/
#
#                                                                          cut
# date
# 2012-04-19 23:12:54+00:00  [I, could, do, it, with, Gen, 1, :, D, Of, cou...
# 2012-06-11 13:16:39+00:00  [You, know, I, put, one, of, the, LED, light, ...
# 2013-01-12 20:09:43+00:00  [Thanks, Richard, ,, I, would, love, it, if, y...
# 2013-01-12 20:22:19+00:00  [I, remember, Buddy, Crisp, at, SEMA, showing,...
# 2013-01-12 21:00:05+00:00  [I, did, find, this, today, on, Youtube, ., Th...

# %% [markdown]
# # 10. 每个用户掌握的关键词数量

# %%
all_words = []
for i in df1["cut"]:
    all_words += i

for i in df2["cut"]:
    all_words += i
    
for i in df3["cut"]:
    all_words += i
    
print(len(all_words))
words_df = pd.DataFrame(all_words, columns=["word"])
words_df.head()
# Out:
# 498409
#    word
# 0   and
# 1   you
# 2   did
# 3     !
# 4  View

# %%
# 频率排名为前20的单词
words_df.groupby("word")["word"].count().sort_values(ascending=False)[:20]
# Out:
# word
# the     23186
# .       19148
# ,       15700
# to      11088
# a        9543
# and      9399
# I        9027
# of       7559
# !        6962
# is       6595
# '        5570
# it       5460
# that     5049
# you      4978
# for      4945
# in       4758
# be       3998
# )        3886
# with     3351
# this     3173
# Name: word, dtype: int64

# %%
def check_impt_word(txt_list):
    count = 0
    for i in txt_list:
        if i in important_words:
            count += 1
    return count

# 关键词列表
important_words = ["the", "to", "and", "a", "I", "of", "is", "it", "you", "that"]

# %%
# 3Dprinter
df1_cut = df1[["user", "cut"]]
df1_cut["关键词数量"] = df1_cut["cut"].apply(check_impt_word)
df1_cut.head()
# Out:
# /Users/nick/.venv/ML-training/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                       user  \
# date
# 2014-04-12 05:05:41+00:00  vasilatos_ianis
# 2014-04-12 15:56:25+00:00      idesigncars
# 2014-04-12 15:56:36+00:00      idesigncars
# 2014-04-12 15:56:50+00:00      idesigncars
# 2014-04-12 15:57:39+00:00      idesigncars
#
#                                                                          cut  \
# date
# 2014-04-12 05:05:41+00:00             [and, you, did, !, View, topic, Reply]
# 2014-04-12 15:56:25+00:00  [This, is, noted, ., C, ', mon, Spoon, ,, you,...
# 2014-04-12 15:56:36+00:00  [Nope, --, see, reply, to, Spoon, View, topic,...
# 2014-04-12 15:56:50+00:00       [Thats, probably, it, ., View, topic, Reply]
# 2014-04-12 15:57:39+00:00  [Paulo, ,, great, question, ., Right, now, the...
#
#                            关键词数量
# date
# 2014-04-12 05:05:41+00:00      2
# 2014-04-12 15:56:25+00:00      4
# 2014-04-12 15:56:36+00:00      1
# 2014-04-12 15:56:50+00:00      1
# 2014-04-12 15:57:39+00:00      7

# %%
df1_cut.groupby("user")["关键词数量"].sum()
# Out:
# user
# AMR                    29
# Adan                   22
# Aurel.                324
# BMWZ8                   5
# BorisSedov              5
# Carline                 0
# Cheshire_cat            3
# Cosmin                 14
# Cristian_F             12
# Dodo_101               39
# DoubleD9570            16
# GTR                   121
# Harlock                59
# Hussien                 9
# Indianmick             12
# KRVZ                  106
# Kalle_Keituri           1
# Karen_Dustry          114
# Late                   18
# Luci_ued               48
# Lude                  135
# MasonBW17               4
# NemoDesigns           118
# PauloItaliani          12
# Qo-Di                   4
# RVink                   6
# Ramarryo               48
# RomainM                16
# TaurusNut              30
# Thipps                  7
#                      ...
# filski                 22
# gabi_hantig            34
# gabriel_r             125
# hamza.g.661             0
# hot_rod_doctor         10
# iMAN                    1
# idesigncars           253
# john_m                 43
# jrogers                 4
# lulu                   48
# magridc                 6
# mandita                38
# marian_cilibeanu       63
# mikeruiz568            12
# namundsen              16
# nikos_m               116
# nwolfy                  9
# oilmon                  2
# petrolhead1992         11
# pierpaololazzarini      7
# prathyush1984           7
# romanogaspari          13
# salsdesign193          16
# samarth0208            44
# sebastian.dib10        11
# spacerodsal            28
# spoon334               22
# thdudesign              7
# vasilatos_ianis       184
# zsolt_laszlo            1
# Name: 关键词数量, Length: 77, dtype: int64

# %%
# LS
df2_cut = df2[["name", "cut"]]
df2_cut["关键词数量"] = df2_cut["cut"].apply(check_impt_word)
df2_cut.head()
# Out:
# /Users/nick/.venv/ML-training/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                                name  \
# time
# 2014-10-20 21:46:27.759440+00:00        idesigncars
# 2014-10-20 20:28:18+00:00                  nfreytag
# 2014-11-06 02:05:33.780373+00:00            rambone
# 2014-11-06 20:48:28.216903+00:00            rambone
# 2014-11-07 11:36:06.644449+00:00  Huynh_ngoc_lan600
#
#                                                                                 cut  \
# time
# 2014-10-20 21:46:27.759440+00:00           [@, karen, _, dustry, ...., Sigh, .....]
# 2014-10-20 20:28:18+00:00         [The, Local, Motors, Sports, Car, Platform, ha...
# 2014-11-06 02:05:33.780373+00:00                          [common, ducati, already]
# 2014-11-06 20:48:28.216903+00:00    [ideas, on, the, MODSTER, modular, sports, car]
# 2014-11-07 11:36:06.644449+00:00                               [S, -, 400, concept]
#
#                                   关键词数量
# time
# 2014-10-20 21:46:27.759440+00:00      0
# 2014-10-20 20:28:18+00:00            21
# 2014-11-06 02:05:33.780373+00:00      0
# 2014-11-06 20:48:28.216903+00:00      1
# 2014-11-07 11:36:06.644449+00:00      0

# %%
df2_cut.groupby("name")["关键词数量"].sum()
# Out:
# name
# A.James                 42
# AC3R1GG1NS              39
# APP                      5
# AdamKeiser               3
# Adan                   302
# Afongartdesign          51
# AlexFi                  31
# Alireza                 30
# ArmDesigner            596
# Artist334              541
# Aurel.                 454
# BM                     525
# BMayesVolsForLocal       5
# BWilkins                84
# Badihtab               252
# Bearon                 293
# BigBlackShark           12
# Billyb                   2
# Blacktulip13           778
# BlankIfYouWill         104
# Blue-Jay              1682
# BluePhoenix             18
# Blue_bee                26
# Brent78232               3
# Buddyz                   8
# CAD-Idesign              0
# CFECO1                   3
# CherAn                  12
# Cjacobs                 59
# Clancey                  3
#                       ...
# videogameslucas99        2
# vitriolic1             171
# vokkoj                   3
# vprime                   2
# vtolmotors               1
# wakeboardmn            181
# wakimball               10
# walshmfg                14
# wbyrne                   4
# whitgatline             22
# willo_dh                83
# woahitch                19
# wooly48                 26
# yankeezrule1315         12
# yasid                  259
# yasser4008             410
# yellowspecv              0
# yinster                  7
# yoitisi                 27
# youknowitsomar170        4
# yunigalindo1             1
# yyrkoon1965            107
# zacharydurren            0
# zano93                  46
# zano99                  98
# zenox                   18
# zetramotors             68
# ziaprogolfer            89
# zura-kakashvili          3
# zz383mero               48
# Name: 关键词数量, Length: 699, dtype: int64

# %%
# RF
df3_cut = df3[["Fuser", "cut"]]
df3_cut["关键词数量"] = df3_cut["cut"].apply(check_impt_word)
df3_cut.head()
# Out:
# /Users/nick/.venv/ML-training/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                   Fuser  \
# date
# 2012-04-19 23:12:54+00:00  Ellocomotive
# 2012-06-11 13:16:39+00:00       moebius
# 2013-01-12 20:09:43+00:00   Tony_Rivera
# 2013-01-12 20:22:19+00:00     RaMansell
# 2013-01-12 21:00:05+00:00     RaMansell
#
#                                                                          cut  \
# date
# 2012-04-19 23:12:54+00:00  [I, could, do, it, with, Gen, 1, :, D, Of, cou...
# 2012-06-11 13:16:39+00:00  [You, know, I, put, one, of, the, LED, light, ...
# 2013-01-12 20:09:43+00:00  [Thanks, Richard, ,, I, would, love, it, if, y...
# 2013-01-12 20:22:19+00:00  [I, remember, Buddy, Crisp, at, SEMA, showing,...
# 2013-01-12 21:00:05+00:00  [I, did, find, this, today, on, Youtube, ., Th...
#
#                            关键词数量
# date
# 2012-04-19 23:12:54+00:00      3
# 2012-06-11 13:16:39+00:00     28
# 2013-01-12 20:09:43+00:00      6
# 2013-01-12 20:22:19+00:00     28
# 2013-01-12 21:00:05+00:00      3

# %%
df3_cut.groupby("Fuser")["关键词数量"].sum()
# Out:
# Fuser
# 1406841095                                                                            0
# Aurel                                                                                45
# DAVID-N                                                                               5
# Ellocomotive                                                                          3
# MattJackson                                                                          48
# RF22                                                                                 10
# RaMansell                                                                           215
# Tony_Rivera                                                                         126
# benleblanc                                                                           30
# dzudzu                                                                                4
# erik260                                                                               5
# gwilson                                                                               2
# https:lm-shop.s3.amazonaws.comuploads7211a434-1141-478e-81cb-763dd1106ced.SLDPRT      5
# idesigncars                                                                         109
# jrogers                                                                              50
# mmartin                                                                               0
# moebius                                                                              28
# tashwill                                                                             77
# wakeboardmn                                                                         599
# Name: 关键词数量, dtype: int64

# %% [markdown]
# # 11. 生成每个项目的词云

# %%
stoplist_wc = ["View", "topic", "and", "Reply", "that", "but",
               "the", "with", "it", "in", "of", "is", "for", 
               "on", "as", "or", "this", "have", "you", "to",
               "are"]

# %%
text_1 = ""
for i in df1["cut"]:
    text_1 += " ".join(i)
    text_1 += " "

cloudobj = wordcloud.WordCloud(font_path = font_path, 
    width = 1200, height = 800,
    mode = "RGBA", background_color = None,
    stopwords = stoplist_wc).generate(text_1)  

plt.imshow(cloudobj)
plt.axis("off")
plt.show()

# %%
text_2 = ""
for i in df2["cut"]:
    text_2 += " ".join(i)
    text_2 += " "

cloudobj = wordcloud.WordCloud(font_path = font_path, 
    width = 1200, height = 800,
    mode = "RGBA", background_color = None,
    stopwords = stoplist_wc).generate(text_2)  

plt.imshow(cloudobj)
plt.axis("off")
plt.show()

# %%
text_3 = ""
for i in df3["cut"]:
    text_3 += " ".join(i)
    text_3 += " "

cloudobj = wordcloud.WordCloud(font_path = font_path, 
    width = 1200, height = 800,
    mode = "RGBA", background_color = None,
    stopwords = stoplist_wc).generate(text_3)  

plt.imshow(cloudobj)
plt.axis("off")
plt.show()
